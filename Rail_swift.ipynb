// %% [markdown]
// <a href="https://colab.research.google.com/github/mnocerino23/Skate-Trick-Combo-Generator/blob/main/Rail_swift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// # Writing the Rail combo function from scratch in Swift. It should be logically very similar to the ledge function with the addition of a few possible rail tricks (e.g. feeble and overcrook)

// %%
!curl "https://raw.githubusercontent.com/philipturner/swift-colab/release/latest/install_swift.sh" --output "install_swift.sh"
!bash "install_swift.sh" "5.6.2"
// Out:
// Compilation error: expression failed to parse:
// <Cell 102>:1:6: error: consecutive statements on a line must be separated by ';'
// !curl "https://raw.githubusercontent.com/philipturner/swift-colab/release/latest/install_swift.sh" --output "install_swift.sh"
//      ^
//      ;
//
// <Cell 102>:1:99: error: consecutive statements on a line must be separated by ';'
// !curl "https://raw.githubusercontent.com/philipturner/swift-colab/release/latest/install_swift.sh" --output "install_swift.sh"
//                                                                                                   ^
//                                                                                                   ;
//
// <Cell 102>:1:108: error: consecutive statements on a line must be separated by ';'
// !curl "https://raw.githubusercontent.com/philipturner/swift-colab/release/latest/install_swift.sh" --output "install_swift.sh"
//                                                                                                            ^
//                                                                                                            ;
//
// <Cell 102>:2:6: error: consecutive statements on a line must be separated by ';'
// !bash "install_swift.sh" "5.6.2"
//      ^
//      ;
//
// <Cell 102>:2:25: error: consecutive statements on a line must be separated by ';'
// !bash "install_swift.sh" "5.6.2"
//                         ^
//                         ;
// : ignored

// %%
//imagine the user has already filled out the survey
//I will provide a sample inventory of tricks so that we can run the function

var my_regular_tricks: [String] = ["ollie", "pop shuv", "front 180", "back 180", "front shuv", "kickflip", "heelflip", "backside flip", 
                                    "back bigspin"]

var my_fakie_tricks: [String] = ["fakie ollie", "fakie pop shuv", "fakie front shuv", "half cab", "fakie front 180", "full cab", 
                                  "fakie front 360","fakie flip", "fakie heel", "fakie bigspin", "fakie front bigspin", 
                                  "half cab flip", "half cab heel", "fakie front heel",
                                "fakie three shuv", "fakie treflip"]

var my_nollie_tricks: [String] = ["nollie", "nollie shuv", "nollie front shuv", "nollie back 180", "nollie front bigspin", 
                                  "nollie back bigspin"]


var my_switch_tricks: [String] = ["switch ollie", "switch front 180", "switch pop shuv"]

var my_rail: [String] = ["front 50-50", "front 5-0", "back 50-50", "back 5-0", "front nosegrind", 
                        "front tail", "front lip", "front feeble", "back feeble", "front boardslide", 
                        "back boardslide", "back overcrook"]

var my_switch_rail: [String] = ["switch back 50-50", "switch front 50-50", "switch front 5-0",
                              "switch front boardslide"]

// %%
//create a dictionary mapping each trick to its exit stance
var exit_stance = ["ollie": "regular", "pop shuv": "regular", "front 180": "fakie", "back 180": "fakie", "front shuv":"regular", "kickflip":"regular", "heelflip":"regular", 
                  "ollie north": "regular", "no comply 180": "fakie",
                  "varial flip":"regular", "varial heel":"regular", "frontside flip":"fakie","backside flip":"fakie", "front heel":"fakie", "back heel":"fakie",
                "back bigspin": "fakie", 
                  "front bigspin":"fakie", 
                  "hardflip":"regular", "inward heel":"regular", "front 360":"regular", "back 360":"regular", "bigflip":"fakie", "bigspin heelflip":"fakie",
                  "treflip": "regular", "360 shuv it": "regular", "impossible":"regular", "lazer flip": "regular", "fakie ollie":"fakie", "fakie pop shuv":"fakie", 
               "fakie front shuv": "fakie", 
                  "half cab": "regular", "fakie front 180": "regular", "full cab":"fakie", "fakie front 360":"fakie", "fakie flip":"fakie", "fakie heel":"fakie",
                "fakie bigspin":"regular", "fakie front bigspin":"regular", "half cab flip":"regular", "half cab heel":"regular", "fakie front heel":"regular",
                 "fakie frontside flip":"regular", "fakie three shuv": "fakie",
                "fakie treflip": "fakie", "full cab flip": "fakie"
                , "fakie bigflip":"regular", "fakie big heel":"regular", "fakie hardflip":"fakie", "fakie inward heel":"fakie", "fakie lazer":"fakie", 
               "fakie varial flip": "fakie", "fakie varial heel": "fakie",
               "nollie":"regular", "nollie shuv":"regular", "nollie front 180":"fakie", "nollie back 180":"fakie", "nollie front shuv":"regular", "nollie flip":"regular", 
                 "nollie heel":"regular", "nollie varial flip":"regular", "nollie varial heel":"regular", "nollie frontside flip":"fakie","nollie backside flip": "regular" , 
               "nollie front heel": "fakie", 
                 "nollie back heel": "fakie", 
                 "nollie front 360 flip": "regular",
                 "nollie back bigspin": "fakie","nollie front bigspin":"fakie", 
                  "nollie hardflip": "regular", "nollie inward heel":"regular", "nollie front 360":"regular", "nollie back 360":"regular", "nollie bigflip":"fakie", 
                  "nollie treflip": "regular", "nollie 360 shuv it": "regular", "nollie big heel":"fakie",  "nollie lazer": "regular", 
                  "manual":"regular", "nose manual": "regular", "fakie manual": "fakie", "switch ollie":"fakie", "switch pop shuv":"fakie", 
                  "switch front 180":"regular", "switch back 180":"regular", "switch front shuv":"fakie", "switch kickflip":"fakie", "switch heel":"fakie", 
                  "switch varial flip": "fakie" , "switch varial heel": "fakie", "switch frontside flip": "regular","switch backside flip":"regular",
                 "switch front heel": "regular", "switch back heel": "regular",
                  "switch back bigspin": "regular", "switch front bigspin":"regular", 
                  "switch hardflip":"regular", "switch inward heel":"fakie", "switch front 360":"fakie", "switch back 360":"fakie", 
                  "switch bigflip":"regular", "switch bigspin heelflip": "regular"
                 , "switch treflip":"fakie", "switch 360 shuv it":"fakie", "switch impossible": "fakie", "switch lazer":"fakie"
]

// %%
//this function gets the common elements of two string arrays and returns an array of the intersection
func get_intersection(list1: Array<String>, list2: Array<String>) -> Array<String> {
  let set1:Set<String> = Set(list1)
  let set2:Set<String> = Set(list2)
  //use the built in swift function that finds the intersect of two sets
  var intersect = set1.intersection(set2)
  //convert intersect to an array and return the array
  var array = [String](intersect)
  return array
}

// %%
var rail = ["back boardslide", "front boardslide", "front 50-50", "back 50-50", "front lip",
            "back lip", "back noseslide", "front noseslide", "front 5-0", "back 5-0", "back feeble", 
            "front feeble", "front smith", "back smith", "front nosegrind", "back nosegrind", 
            "front suski", "back suski","front salad", "back salad", "front blunt", "back blunt", 
            "back crook", "front crook", "front overcrook", "back overcrook", "front tail", "back tail"]

var can_180_into_rail = ["front 50-50", "front 5-0", "back 50-50", "back 5-0", "front nosegrind", "back nosegrind", 
                    "front crook", "back crook", "front smith", "back smith", "front salad",
                    "back salad", "front suski", "back suski", "front feeble", "back feeble", 
                    "switch front 50-50", "switch front 5-0", "switch back 50-50", "switch back 5-0", "switch front nosegrind", 
                    "switch back nosegrind", "switch front crook", "switch back crook", "switch front smith", 
                    "switch back smith", "switch front salad",
                    "switch back salad", "switch front suski", "switch back suski", "switch front feeble", "switch back feeble"]

var exit_either_rail_1 = ["front 50-50", "back 50-50", "back boardslide", "front boardslide", "front lip", "back lip"]

var exit_either_rail_2 = ["switch 50-50", "fakie 50-50", "switch back boardslide", "switch front boardslide",
                      "switch front lip", "switch back lip"]

var exit_nollie_rail = ["front nosegrind", "back nosegrind", "back noseslide", "front noselide", "front crook", 
                  "back crook", "back noseblunt", "front noseblunt", "back overcrook", "front overcrook"]

var exit_regular_rail = ["front tail", "back tail", "front 5-0", "back 5-0", "back suski", "front suski",
                    "front smith", "back smith", "front blunt", "back blunt", "front lip", "back lip",
                    "front salad", "back salad", "front feeble", "back feeble"]

var exit_switch_rail = ["switch tail", "switch 5-0", "switch suski", "switch smith", "switch salad", "switch blunt", 
                   "switch lip", "switch feeble", "fakie noseslide", "fakie nosegrind", "fakie crook", "fakie noseblunt"]

//stance_on_rail = fakie, front truck/tail grinding/sliding
var exit_fakie_rail = ["fakie 5-0", "fakie suski", "fakie smith", "fakie tail",
                  "fakie blunt", "fakie lip", "switch nosegrind", 
                  "switch noseslide", "switch crook",  "switch noseblunt", "fakie feeble"]

var to_fakie = ["back boardslide", "front boardslide", "front lip", "back lip", "back feeble",
                "front feeble", "front blunt", "back blunt", "front noseblunt", "back noseblunt",
                "front crook", "back crook", "front tail", "back tail", "switch boardslide", "switch lip",
                "switch feeble", "switch blunt", "switch noseblunt", "switch crook", "switch tail", "fakie boardslide",
                "fakie lip", "fakie feeble", "fakie blunt", "fakie noseblunt", "fakie crook", "fakie tail"]

var default_out = ["to fakie", "to regular"]

// %%
import Foundation

// %% [markdown]
// Last thing we need is tricks that are taken 'to fakie' or 'to regular' where it's not considered a trick out. This applies for: boardslides, lipslides,
// feeble,blunt, noseblunt, front crook, back crook, front tail, back tail

// %%
func rail_combo_regular(trick_in: Bool, trick_out: Bool) -> String {

  var must_land_regular: Bool = false
  var onto_rail:String = ""
  var stance_entering_rail: String = ""
  var grind_name: String = ""
  var rail_trick: String = ""
  var stance_out:[String]
  var exit_trick: String = ""
  var grind_stance: [String] = ["switch", "fakie"]

  //check to see if the rider has any fakie or switch tricks. If they don't, the trick onto the rail must land in regular stance so
  //they can get off the rail
  if(my_fakie_tricks.count == 0 && my_switch_tricks.count == 0) {
     must_land_regular = true
  }
  else{
     must_land_regular = false
  }

  if (trick_in == true) {
    onto_rail = my_regular_tricks.randomElement()!
    stance_entering_rail = exit_stance[onto_rail]!
    while(onto_rail == "ollie"){
      onto_rail = my_regular_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    while (must_land_regular ==  true && stance_entering_rail == "fakie"){
      //if they can't do fakie/switch manuals and are landing in that stance we must rechoose the trick in at random
      onto_rail = my_regular_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
      while(onto_rail == "ollie"){
      onto_rail = my_regular_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
  }
    
  }
  else{
    stance_entering_rail = "regular"
    onto_rail = "ollie"
  }
    

  //choose the rail trick
  if (stance_entering_rail == "regular"){
    rail_trick = my_rail.randomElement()!
  }

  else{
  //
  //must choose a ledge trick that can be 180'd into. Random choice between fakie ledge trick and switch
    if (my_switch_rail.count > 0){
    //choose random between fakie and switch
      let rail_stance = grind_stance.randomElement()!
      if (rail_stance == "switch"){
        //chose a switch ledge trick
        let grind_choices = get_intersection(list1: my_switch_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        grind_name = selected.components(separatedBy: " ")[2]
        rail_trick =  "switch " + grind_name
      }
      else{
        let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        //split the string
        grind_name = selected.components(separatedBy: " ")[1]
        rail_trick = "fakie " +  grind_name
      }
    }
      //must choose a rail trick that can be 180'd into
      //find the intersect between my_rail and the tricks that can be 180'd into and choose a random one of these
    else{
      let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
      var selected = grind_choices.randomElement()!
      //split the string
      grind_name = selected.components(separatedBy: " ")[1]
      rail_trick = "fakie " +  grind_name
    }
  }
  

  //choose the trick out
  if (trick_out == true){
    //case 1: enter rail in regular and grinding/sliding on both trucks
    if (stance_entering_rail == "regular" && exit_either_rail_1.contains(rail_trick)){
      //if they have nollie tricks, choose a random stance between nollie and regular and choose a random trick in the chosen stance
      if (my_nollie_tricks.count > 0) {
        let array = [my_regular_tricks, my_nollie_tricks]
        stance_out = array.randomElement()!
      }
        
      //else choose regular stance for  trick out
      else{
        stance_out = my_regular_tricks
      }

      exit_trick = stance_out.randomElement()!
      while (exit_trick == "ollie" || exit_trick == "nollie"){
        exit_trick = stance_out.randomElement()!
      }
    }

    //case 2: enter rail in regular and grinding/sliding on the nose
    else if (stance_entering_rail == "regular" && exit_nollie_rail.contains(rail_trick)){
      exit_trick = my_nollie_tricks.randomElement()!
      while (exit_trick == "nollie"){
        exit_trick = my_nollie_tricks.randomElement()!
      }
    }
      
    //case 3: enter rail in regular and grinding/sliding on the tail
    else if (stance_entering_rail == "regular" && exit_regular_rail.contains(rail_trick)) {
      exit_trick = my_regular_tricks.randomElement()!
      while (exit_trick == "ollie") {
        exit_trick = my_regular_tricks.randomElement()!
      }
    }
     

    //case 4: enter rail in fakie and grinding on both trucks
    else if (stance_entering_rail == "fakie" && exit_either_rail_2.contains(rail_trick)){
    //see if they have any switch tricks that could be chosen to get off the rail
      if (my_switch_tricks.count > 0) {
        let stances = [my_fakie_tricks, my_switch_tricks]
        stance_out = stances.randomElement()!
      }
      //else choose fakie trick out
      else{
        stance_out = my_fakie_tricks
      }
      //choose random trick
      exit_trick = stance_out.randomElement()!
      while(exit_trick == "fakie ollie" || exit_trick == "switch ollie"){
          exit_trick = stance_out.randomElement()!
      }
    }

    //case 5: enter rail in fakie and grinding/sliding on the nose (e.g. back 180 nosegrind)
    else if (stance_entering_rail == "fakie" && exit_fakie_rail.contains(rail_trick)){
      exit_trick = my_fakie_tricks.randomElement()!
      while (exit_trick == "fakie ollie") {
        exit_trick = my_fakie_tricks.randomElement()!
      }
    }

    //case 6: enter rail in fakie and grinding/sliding on the tail (e.g. back 180, fakie 5-0)
    else {
      exit_trick = my_switch_tricks.randomElement()!
      while (exit_trick == "switch ollie") {
        exit_trick = my_switch_tricks.randomElement()!
      }
    }

    

    return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
  }
    
  else{
    //if no trick out, print onto rail and rail trick
    //choose random to regular or to fakie
    if to_fakie.contains(rail_trick){
      exit_trick = default_out.randomElement()!
      return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
    }
    else{
      return("\(onto_rail) - \(rail_trick)")
    }
  }
}

// %%
rail_combo_regular(trick_in: true, trick_out: true)
// Out:
// "heelflip - front boardslide - nollie back bigspin"

// %%
func rail_combo_fakie(trick_in: Bool, trick_out: Bool) -> String {

  var must_land_regular: Bool = false
  var onto_rail:String = ""
  var stance_entering_rail: String = ""
  var grind_name: String = ""
  var rail_trick: String = ""
  var stance_out:[String]
  var exit_trick: String = ""
  var grind_stance: [String] = ["switch", "fakie"]


  //check to see if the rider has any fakie or switch tricks. If they don't, the trick onto the rail must land in regular stance so
  //they can get off the rail
  if(my_fakie_tricks.count == 0 && my_switch_tricks.count == 0) {
     must_land_regular = true
  }
  else{
     must_land_regular = false
  }

  if (trick_in == true) {
    onto_rail = my_fakie_tricks.randomElement()!
    stance_entering_rail = exit_stance[onto_rail]!
    while(onto_rail == "fakie ollie"){
      onto_rail = my_fakie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    while (must_land_regular ==  true && stance_entering_rail == "fakie"){
      //if they can't do fakie/switch manuals and are landing in that stance we must rechoose the trick in at random
      onto_rail = my_fakie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
      while(onto_rail == "fakie ollie"){
      onto_rail = my_fakie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    }
    
  }
  else{
    stance_entering_rail = "fakie"
    onto_rail = "fakie ollie"
  }
    

  //choose the rail trick
  if (stance_entering_rail == "regular"){
    rail_trick = my_rail.randomElement()!
  }

  else{
   //
  //must choose a ledge trick that can be 180'd into. Random choice between fakie ledge trick and switch
    if (my_switch_rail.count > 0){
    //choose random between fakie and switch
      let rail_stance = grind_stance.randomElement()!
      if (rail_stance == "switch"){
        //chose a switch ledge trick
        let grind_choices = get_intersection(list1: my_switch_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        grind_name = selected.components(separatedBy: " ")[2]
        rail_trick =  "switch " + grind_name
      }
      else{
        let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        //split the string
        grind_name = selected.components(separatedBy: " ")[1]
        rail_trick = "fakie " +  grind_name
      }
    }
      //must choose a rail trick that can be 180'd into
      //find the intersect between my_rail and the tricks that can be 180'd into and choose a random one of these
    else{
      let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
      var selected = grind_choices.randomElement()!
      //split the string
      grind_name = selected.components(separatedBy: " ")[1]
      rail_trick = "fakie " +  grind_name
    }
  }
  

  //choose the trick out
  if (trick_out == true){
    //case 1: enter rail in regular and grinding/sliding on both trucks
    if (stance_entering_rail == "regular" && exit_either_rail_1.contains(rail_trick)){
      //if they have nollie tricks, choose a random stance between nollie and regular and choose a random trick in the chosen stance
      if (my_nollie_tricks.count > 0) {
        let array = [my_regular_tricks, my_nollie_tricks]
        stance_out = array.randomElement()!
      }
        
      //else choose regular stance for  trick out
      else{
        stance_out = my_regular_tricks
      }

      exit_trick = stance_out.randomElement()!
      while (exit_trick == "ollie" || exit_trick == "nollie"){
        exit_trick = stance_out.randomElement()!
      }
    }

    //case 2: enter rail in regular and grinding/sliding on the nose
    else if (stance_entering_rail == "regular" && exit_nollie_rail.contains(rail_trick)){
      exit_trick = my_nollie_tricks.randomElement()!
      while (exit_trick == "nollie"){
        exit_trick = my_nollie_tricks.randomElement()!
      }
    }
      
    //case 3: enter rail in regular and grinding/sliding on the tail
    else if (stance_entering_rail == "regular" && exit_regular_rail.contains(rail_trick)) {
      exit_trick = my_regular_tricks.randomElement()!
      while (exit_trick == "ollie") {
        exit_trick = my_regular_tricks.randomElement()!
      }
    }
     

    //case 4: enter rail in fakie and grinding on both trucks
    else if (stance_entering_rail == "fakie" && exit_either_rail_2.contains(rail_trick)){
    //see if they have any switch tricks that could be chosen to get off the rail
      if (my_switch_tricks.count > 0) {
        let stances = [my_fakie_tricks, my_switch_tricks]
        stance_out = stances.randomElement()!
      }
      //else choose fakie trick out
      else{
        stance_out = my_fakie_tricks
      }
      //choose random trick
      exit_trick = stance_out.randomElement()!
      while(exit_trick == "fakie ollie" || exit_trick == "switch ollie"){
          exit_trick = stance_out.randomElement()!
      }
    }

    //case 5: enter rail in fakie and grinding/sliding on the nose (e.g. back 180 nosegrind)
    else if (stance_entering_rail == "fakie" && exit_fakie_rail.contains(rail_trick)){
      exit_trick = my_fakie_tricks.randomElement()!
      while (exit_trick == "fakie ollie") {
        exit_trick = my_fakie_tricks.randomElement()!
      }
    }

    //case 6: enter rail in fakie and grinding/sliding on the tail (e.g. back 180, fakie 5-0)
    else {
      exit_trick = my_switch_tricks.randomElement()!
      while (exit_trick == "switch ollie") {
        exit_trick = my_switch_tricks.randomElement()!
      }
    }

    

    return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
  }
    
  else{
    //if no trick out, print onto rail and rail trick
    //choose random to regular or to fakie
    if to_fakie.contains(rail_trick){
      exit_trick = default_out.randomElement()!
      return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
    }
    else{
      return("\(onto_rail) - \(rail_trick)")
    }
  }
}

// %%
func rail_combo_nollie(trick_in: Bool, trick_out: Bool) -> String {

  var must_land_regular: Bool = false
  var onto_rail:String = ""
  var stance_entering_rail: String = ""
  var grind_name: String = ""
  var rail_trick: String = ""
  var stance_out:[String]
  var exit_trick: String = ""
  var grind_stance: [String] = ["switch", "fakie"]


  //check to see if the rider has any fakie or switch tricks. If they don't, the trick onto the rail must land in regular stance so
  //they can get off the rail
  if(my_fakie_tricks.count == 0 && my_switch_tricks.count == 0) {
     must_land_regular = true
  }
  else{
     must_land_regular = false
  }

  if (trick_in == true) {
    onto_rail = my_nollie_tricks.randomElement()!
    stance_entering_rail = exit_stance[onto_rail]!
    while(onto_rail == "nollie"){
      onto_rail = my_nollie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    while (must_land_regular ==  true && stance_entering_rail == "fakie"){
      //if they can't do fakie/switch manuals and are landing in that stance we must rechoose the trick in at random
      onto_rail = my_nollie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
      while(onto_rail == "nollie"){
      onto_rail = my_nollie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    }
    
  }
  else{
    stance_entering_rail = "regular"
    onto_rail = "nollie"
  }
    

   //choose the rail trick
  if (stance_entering_rail == "regular"){
    rail_trick = my_rail.randomElement()!
  }

  else{
       //
  //must choose a ledge trick that can be 180'd into. Random choice between fakie ledge trick and switch
    if (my_switch_rail.count > 0){
    //choose random between fakie and switch
      let rail_stance = grind_stance.randomElement()!
      if (rail_stance == "switch"){
        //chose a switch ledge trick
        let grind_choices = get_intersection(list1: my_switch_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        grind_name = selected.components(separatedBy: " ")[2]
        rail_trick =  "switch " + grind_name
      }
      else{
        let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        //split the string
        grind_name = selected.components(separatedBy: " ")[1]
        rail_trick = "fakie " +  grind_name
      }
    }
      //must choose a rail trick that can be 180'd into
      //find the intersect between my_rail and the tricks that can be 180'd into and choose a random one of these
    else{
      let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
      var selected = grind_choices.randomElement()!
      //split the string
      grind_name = selected.components(separatedBy: " ")[1]
      rail_trick = "fakie " +  grind_name
    }
  }
  

  //choose the trick out
  if (trick_out == true){
    //case 1: enter rail in regular and grinding/sliding on both trucks
    if (stance_entering_rail == "regular" && exit_either_rail_1.contains(rail_trick)){
      //if they have nollie tricks, choose a random stance between nollie and regular and choose a random trick in the chosen stance
      if (my_nollie_tricks.count > 0) {
        let array = [my_regular_tricks, my_nollie_tricks]
        stance_out = array.randomElement()!
      }
        
      //else choose regular stance for  trick out
      else{
        stance_out = my_regular_tricks
      }

      exit_trick = stance_out.randomElement()!
      while (exit_trick == "ollie" || exit_trick == "nollie"){
        exit_trick = stance_out.randomElement()!
      }
    }

    //case 2: enter rail in regular and grinding/sliding on the nose
    else if (stance_entering_rail == "regular" && exit_nollie_rail.contains(rail_trick)){
      exit_trick = my_nollie_tricks.randomElement()!
      while (exit_trick == "nollie"){
        exit_trick = my_nollie_tricks.randomElement()!
      }
    }
      
    //case 3: enter rail in regular and grinding/sliding on the tail
    else if (stance_entering_rail == "regular" && exit_regular_rail.contains(rail_trick)) {
      exit_trick = my_regular_tricks.randomElement()!
      while (exit_trick == "ollie") {
        exit_trick = my_regular_tricks.randomElement()!
      }
    }
     

    //case 4: enter rail in fakie and grinding on both trucks
    else if (stance_entering_rail == "fakie" && exit_either_rail_2.contains(rail_trick)){
    //see if they have any switch tricks that could be chosen to get off the rail
      if (my_switch_tricks.count > 0) {
        let stances = [my_fakie_tricks, my_switch_tricks]
        stance_out = stances.randomElement()!
      }
      //else choose fakie trick out
      else{
        stance_out = my_fakie_tricks
      }
      //choose random trick
      exit_trick = stance_out.randomElement()!
      while(exit_trick == "fakie ollie" || exit_trick == "switch ollie"){
          exit_trick = stance_out.randomElement()!
      }
    }

    //case 5: enter rail in fakie and grinding/sliding on the nose (e.g. back 180 nosegrind)
    else if (stance_entering_rail == "fakie" && exit_fakie_rail.contains(rail_trick)){
      exit_trick = my_fakie_tricks.randomElement()!
      while (exit_trick == "fakie ollie") {
        exit_trick = my_fakie_tricks.randomElement()!
      }
    }

    //case 6: enter rail in fakie and grinding/sliding on the tail (e.g. back 180, fakie 5-0)
    else {
      exit_trick = my_switch_tricks.randomElement()!
      while (exit_trick == "switch ollie") {
        exit_trick = my_switch_tricks.randomElement()!
      }
    }

    

    return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
  }
    
  else{
    //if no trick out, print onto rail and rail trick
    //choose random to regular or to fakie
    if to_fakie.contains(rail_trick){
      exit_trick = default_out.randomElement()!
      return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
    }
    else{
      return("\(onto_rail) - \(rail_trick)")
    }
  }
}

// %%
func rail_combo_switch(trick_in: Bool, trick_out: Bool) -> String {

  var must_land_regular: Bool = false
  var onto_rail:String = ""
  var stance_entering_rail: String = ""
  var grind_name: String = ""
  var rail_trick: String = ""
  var stance_out:[String]
  var exit_trick: String = ""
  var grind_stance: [String] = ["switch", "fakie"]

  //check to see if the rider has any fakie or switch tricks. If they don't, the trick onto the rail must land in regular stance so
  //they can get off the rail
  if(my_fakie_tricks.count == 0 && my_switch_tricks.count == 0) {
     must_land_regular = true
  }
  else{
     must_land_regular = false
  }

  if (trick_in == true) {
    onto_rail = my_switch_tricks.randomElement()!
    stance_entering_rail = exit_stance[onto_rail]!
    while(onto_rail == "switch ollie"){
      onto_rail = my_nollie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    while (must_land_regular ==  true && stance_entering_rail == "fakie"){
      //if they can't do fakie/switch manuals and are landing in that stance we must rechoose the trick in at random
      onto_rail = my_nollie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
      while(onto_rail == "switch ollie"){
      onto_rail = my_nollie_tricks.randomElement()!
      stance_entering_rail = exit_stance[onto_rail]!
    }
    }
    
  }
  else{
    stance_entering_rail = "fakie"
    onto_rail = "switch ollie"
  }
    

  //choose the rail trick
  if (stance_entering_rail == "regular"){
    rail_trick = my_rail.randomElement()!
  }

  else{
     //
  //must choose a ledge trick that can be 180'd into. Random choice between fakie ledge trick and switch
    if (my_switch_rail.count > 0){
    //choose random between fakie and switch
      let rail_stance = grind_stance.randomElement()!
      if (rail_stance == "switch"){
        //chose a switch ledge trick
        let grind_choices = get_intersection(list1: my_switch_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        grind_name = selected.components(separatedBy: " ")[2]
        rail_trick =  "switch " + grind_name
      }
      else{
        let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
        var selected = grind_choices.randomElement()!
        //split the string
        grind_name = selected.components(separatedBy: " ")[1]
        rail_trick = "fakie " +  grind_name
      }
    }
      //must choose a rail trick that can be 180'd into
      //find the intersect between my_rail and the tricks that can be 180'd into and choose a random one of these
    else{
      let grind_choices = get_intersection(list1: my_rail, list2: can_180_into_rail)
      var selected = grind_choices.randomElement()!
      //split the string
      grind_name = selected.components(separatedBy: " ")[1]
      rail_trick = "fakie " +  grind_name
    }
  }
  

  //choose the trick out
  if (trick_out == true){
    //case 1: enter rail in regular and grinding/sliding on both trucks
    if (stance_entering_rail == "regular" && exit_either_rail_1.contains(rail_trick)){
      //if they have nollie tricks, choose a random stance between nollie and regular and choose a random trick in the chosen stance
      if (my_nollie_tricks.count > 0) {
        let array = [my_regular_tricks, my_nollie_tricks]
        stance_out = array.randomElement()!
      }
        
      //else choose regular stance for  trick out
      else{
        stance_out = my_regular_tricks
      }

      exit_trick = stance_out.randomElement()!
      while (exit_trick == "ollie" || exit_trick == "nollie"){
        exit_trick = stance_out.randomElement()!
      }
    }

    //case 2: enter rail in regular and grinding/sliding on the nose
    else if (stance_entering_rail == "regular" && exit_nollie_rail.contains(rail_trick)){
      exit_trick = my_nollie_tricks.randomElement()!
      while (exit_trick == "nollie"){
        exit_trick = my_nollie_tricks.randomElement()!
      }
    }
      
    //case 3: enter rail in regular and grinding/sliding on the tail
    else if (stance_entering_rail == "regular" && exit_regular_rail.contains(rail_trick)) {
      exit_trick = my_regular_tricks.randomElement()!
      while (exit_trick == "ollie") {
        exit_trick = my_regular_tricks.randomElement()!
      }
    }
     

    //case 4: enter rail in fakie and grinding on both trucks
    else if (stance_entering_rail == "fakie" && exit_either_rail_2.contains(rail_trick)){
    //see if they have any switch tricks that could be chosen to get off the rail
      if (my_switch_tricks.count > 0) {
        let stances = [my_fakie_tricks, my_switch_tricks]
        stance_out = stances.randomElement()!
      }
      //else choose fakie trick out
      else{
        stance_out = my_fakie_tricks
      }
      //choose random trick
      exit_trick = stance_out.randomElement()!
      while(exit_trick == "fakie ollie" || exit_trick == "switch ollie"){
          exit_trick = stance_out.randomElement()!
      }
    }

    //case 5: enter rail in fakie and grinding/sliding on the nose (e.g. back 180 nosegrind)
    else if (stance_entering_rail == "fakie" && exit_fakie_rail.contains(rail_trick)){
      exit_trick = my_fakie_tricks.randomElement()!
      while (exit_trick == "fakie ollie") {
        exit_trick = my_fakie_tricks.randomElement()!
      }
    }

    //case 6: enter rail in fakie and grinding/sliding on the tail (e.g. back 180, fakie 5-0)
    else {
      exit_trick = my_switch_tricks.randomElement()!
      while (exit_trick == "switch ollie") {
        exit_trick = my_switch_tricks.randomElement()!
      }
    }

    

    return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
  }
    else{
      //if no trick out, print onto rail and rail trick
      //choose random to regular or to fakie
      if to_fakie.contains(rail_trick){
        exit_trick = default_out.randomElement()!
        return("\(onto_rail) - \(rail_trick) - \(exit_trick)")
      }
      else{
        return("\(onto_rail) - \(rail_trick)")
      }
    }
}

// %%
func rail_combo(trick_enter: Bool, trick_exit: Bool) -> String {
  var stances: [String] = ["regular", "fakie", "nollie", "switch"]
  var enter_stance: String = ""

  //choose a random stance and then run the appropriate function given the random
  //entry stance selected
  enter_stance = stances.randomElement()!
  if (enter_stance == "regular"){
    return rail_combo_regular(trick_in: trick_enter, trick_out: trick_exit)
  }

  else if (enter_stance == "fakie"){
    return rail_combo_fakie(trick_in: trick_enter, trick_out: trick_exit)
  }

  else if (enter_stance == "nollie"){
    return rail_combo_nollie(trick_in: trick_enter, trick_out: trick_exit)
  }

  //case 4: enter_stance is switch
  else{
    return rail_combo_switch(trick_in: trick_enter, trick_out: trick_exit)
  }
}

// %%
for i in 1...15{
  print(i)
  print(rail_combo(trick_enter: false, trick_exit: true))
  print(rail_combo(trick_enter: true, trick_exit: false))
  print(rail_combo(trick_enter: true, trick_exit: true))
}
// Out:
// 1
// nollie - front feeble - pop shuv
// switch front 180 - back 50-50
// nollie shuv - back boardslide - front shuv
// 2
// fakie ollie - fakie 5-0 - fakie front shuv
// nollie back bigspin - switch 50-50
// nollie front shuv - back overcrook - nollie front shuv
// 3
// ollie - front boardslide - front 180
// pop shuv - front boardslide - to regular
// switch pop shuv - switch 50-50 - fakie front 180
// 4
// switch ollie - switch 5-0 - switch front 180
// back 180 - fakie 50-50
// nollie shuv - front lip - kickflip
// 5
// switch ollie - fakie 50-50 - switch pop shuv
// nollie front shuv - back overcrook
// nollie front shuv - back boardslide - heelflip
// 6
// nollie - front lip - back 180
// fakie flip - switch 50-50
// fakie treflip - fakie 5-0 - fakie front shuv
// 7
// nollie - front tail - backside flip
// nollie back 180 - switch 50-50
// nollie back bigspin - switch 50-50 - switch front 180
// 8
// ollie - front tail - kickflip
// front 180 - switch 50-50
// switch pop shuv - switch 50-50 - switch front 180
// 9
// fakie ollie - switch 50-50 - switch front 180
// pop shuv - front nosegrind
// backside flip - switch 5-0 - switch front 180
// 10
// switch ollie - fakie nosegrind - switch pop shuv
// fakie flip - switch 50-50
// nollie front bigspin - switch 5-0 - switch pop shuv
// 11
// ollie - front 5-0 - pop shuv
// nollie shuv - front lip - to regular
// nollie back bigspin - fakie 50-50 - half cab flip
// 12
// switch ollie - fakie 5-0 - half cab flip
// nollie back bigspin - fakie 50-50
// nollie front bigspin - fakie 5-0 - fakie treflip
// 13
// ollie - back feeble - kickflip
// front shuv - front 5-0
// nollie shuv - front boardslide - heelflip
// 14
// nollie - front nosegrind - nollie back 180
// switch front 180 - back feeble - to regular
// switch pop shuv - fakie 50-50 - half cab heel
// 15
// nollie - back 50-50 - nollie back 180
// backside flip - fakie 50-50
// fakie front shuv - switch 5-0 - switch pop shuv
